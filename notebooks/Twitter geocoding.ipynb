# %%
#Mount Google Drive if running in Colab

from google.colab import drive
drive.mount('/content/drive/')

filepath = '/content/drive/MyDrive/DS_Capstone/'
# Out:
# Mounted at /content/drive/

# %%
#Import libraries and set graphics styles

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from datetime import timedelta
import warnings
warnings.filterwarnings('ignore')

# Set style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# %%
# Load X/Twitter data
print("\n1.2 Loading X/Twitter data...")
twitter_file = filepath + "Bird_flu/_H5N1_ -is_retweet since_2022-06-01 until_2025-01-01 lang_en.csv"
twitter = pd.read_csv(twitter_file, low_memory=False)
twitter['createdAt'] = pd.to_datetime(twitter['createdAt'], utc=True, errors='coerce')
twitter.dropna(subset=['createdAt'], inplace=True) # Drop rows with NaT in 'createdAt'
twitter['createdAt'] = twitter['createdAt'].dt.tz_convert(None)
twitter['date'] = twitter['createdAt'].dt.date
twitter = twitter.sort_values('createdAt')
# Out:
# 1.2 Loading X/Twitter data...
# ✓ Loaded 183,185 tweets
#   Date range: 2022-06-01 01:19:03 to 2024-12-31 23:59:41

# %%
twitter
# Out:
#                         _id               userId             userName  \
# 20838   1531807504845398017             14777416      Krissy Klabacha
# 20837   1531822538396946437  1204093660880678913    Md. Ekramul Karim
# 20836   1531877472253448192             18932416         Louise Hosie
# 20835   1531921969582596096            239996081        Nigel Bennett
# 20834   1531930248597622785  1464367421217718275  Margaret Taylor PhD
# ...                     ...                  ...                  ...
# 121502  1874243879769428458  1728929146833625088             Mary Kay
# 121501  1874243965203210478           2148517162               Thomas
# 121500  1874243968466379120  1448822071803277315       Kate Pritchard
# 121499  1874243979505766755             15910110       Shana Bates RN
# 121498  1874244065468047835  1407525472083140615            I Dissent
#
#                   alias                                     profilePicture  \
# 20838        presquevoo  https://pbs.twimg.com/profile_images/264804069...
# 20837   MdEkramulKarim1  https://pbs.twimg.com/profile_images/120409419...
# 20836      louise_hosie  https://pbs.twimg.com/profile_images/167849633...
# 20835    top1percentile  https://pbs.twimg.com/profile_images/122098430...
# 20834        MgtTaylor1  https://pbs.twimg.com/profile_images/146437284...
# ...                 ...                                                ...
# 121502      MMahon43573  https://pbs.twimg.com/profile_images/174551449...
# 121501      kotkowskitj  https://pbs.twimg.com/profile_images/378800000...
# 121500  antiglobalism10  https://pbs.twimg.com/profile_images/185411257...
# 121499       shanabates  https://pbs.twimg.com/profile_images/468412917...
# 121498        DissentFu  https://pbs.twimg.com/profile_images/154565056...
#
#                    userCreatedAt  \
# 20838   2008-05-14T19:35:08.000Z
# 20837   2019-12-09T17:41:36.000Z
# 20836   2009-01-13T07:45:06.000Z
# 20835   2011-01-18T22:49:05.000Z
# 20834   2021-11-26T22:56:50.000Z
# ...                          ...
# 121502  2023-11-27T00:10:18.000Z
# 121501  2013-10-22T13:51:03.000Z
# 121500  2021-10-15T01:25:08.000Z
# 121499  2008-08-19T21:50:46.000Z
# 121498  2021-06-23T02:26:48.000Z
#
#                                                       bio followers following  \
# 20838   talker; typer; consumer; thinker; dancing pupp...        89       425
# 20837   Microbiome; Host-Microbe Interactions; Microbi...       435      2094
# 20836   Senior Journalist @BBCScotlandNews. Ex-@stvnew...      3947      5053
# 20835   Scientist technologist and maverick philosophe...      7642      1918
# 20834   Cell Biol Uni St Andrews/Influenza/Science/Cli...       261      1774
# ...                                                   ...       ...       ...
# 121502  Curiosity killed the cat; but answers always b...       276       869
# 121501  Retired Marine. Truth teller not afraid of the...      2294      1656
# 121500  Atheist British/AustralianEx Aid Worker Wester...      2313      1219
# 121499                                   Registered Nurse      1421      4321
# 121498  MaskUp. Free Palestine. Mad that I wasted 1000...      3489      4050
#
#        lists  ... images impressions isImage firstImage  \
# 20838      0  ...     []         0.0   False        NaN
# 20837      4  ...     []         0.0   False        NaN
# 20836    127  ...     []         0.0   False        NaN
# 20835     69  ...     []         0.0   False        NaN
# 20834      1  ...     []         0.0   False        NaN
# ...      ...  ...    ...         ...     ...        ...
# 121502     1  ...     []      8132.0   False        NaN
# 121501     5  ...     []       605.0   False        NaN
# 121500    29  ...     []     17435.0   False        NaN
# 121499    20  ...     []        36.0   False        NaN
# 121498    10  ...     []       196.0   False        NaN
#
#                               location  \
# 20838               Chicagoland mostly
# 20837                       Houston TX
# 20836          Scotland United Kingdom
# 20835                          England
# 20834          Scotland United Kingdom
# ...                                ...
# 121502                             NaN
# 121501                   Massachusetts
# 121500                        🇦🇺🇬🇧🇮🇱🇺🇸
# 121499                      Deep South
# 121498  In the last gasp of capitalism
#
#                                                   url noteTweetText  \
# 20838   https://x.com/user/status/1531807504845398017           NaN
# 20837   https://x.com/user/status/1531822538396946437           NaN
# 20836   https://x.com/user/status/1531877472253448192           NaN
# 20835   https://x.com/user/status/1531921969582596096           NaN
# 20834   https://x.com/user/status/1531930248597622785           NaN
# ...                                               ...           ...
# 121502  https://x.com/user/status/1874243879769428458           NaN
# 121501  https://x.com/user/status/1874243965203210478           NaN
# 121500  https://x.com/user/status/1874243968466379120           NaN
# 121499  https://x.com/user/status/1874243979505766755           NaN
# 121498  https://x.com/user/status/1874244065468047835           NaN
#
#        retweetedUserId reportName        date
# 20838              NaN        NaN  2022-06-01
# 20837              NaN        NaN  2022-06-01
# 20836              NaN        NaN  2022-06-01
# 20835              NaN        NaN  2022-06-01
# 20834              NaN        NaN  2022-06-01
# ...                ...        ...         ...
# 121502             NaN        NaN  2024-12-31
# 121501             NaN        NaN  2024-12-31
# 121500             NaN        NaN  2024-12-31
# 121499             NaN        NaN  2024-12-31
# 121498             NaN        NaN  2024-12-31
#
# [183185 rows x 33 columns]

# %%
twitter.shape
# Out:
# (183185, 33)

# %%
pip install geopy pycountry
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Collecting pycountry
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.1)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 57.9 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-24.6.1

# %%
"""
Twitter Location Extraction - CORRECTED VERSION
Fix: Proper dataframe application to avoid row misalignment
"""

import pandas as pd
import re
from typing import Optional, Dict


class LocationExtractor:
    """Extract and validate locations from Twitter location strings"""

    def __init__(self):
        # Invalid patterns to filter out
        self.invalid_patterns = [
            r'\b(everywhere|nowhere|internet|online|cyberspace|virtual|worldwide)\b',
            r'\b(earth|world|globe|universe|metaverse)\b',
            r'\b(on-chain|in the club)\b',
            r'international website',
        ]

        # Location aliases and normalizations
        self.aliases = {
            'chicagoland': 'Chicago',
            'chicagoland mostly': 'Chicago, Illinois',
            'chicagoland, mostly': 'Chicago, Illinois',
            'the free state of florida': 'Florida',
            'houston tx': 'Houston, Texas',
            'houston, tx': 'Houston, Texas',
            'washington dc': 'Washington DC',
            'washington, dc': 'Washington DC',
            'vancouver': 'Vancouver, Canada',
            'scotland united kingdom': 'Scotland, UK',
            'scotland, united kingdom': 'Scotland, UK',
            'england': 'England, UK',
            'uk': 'United Kingdom',
            'u.k.': 'United Kingdom',
            'gb': 'United Kingdom',
            'usa': 'United States',
            'us': 'United States',
            'u.s.': 'United States',
            'u.s.a.': 'United States',
            'uae': 'United Arab Emirates',
            'u.a.e.': 'United Arab Emirates',
            'ksa': 'Saudi Arabia',
            'nz': 'New Zealand',
            'oz': 'Australia',
            'aus': 'Australia',
        }

        # Known countries for extraction
        self.countries = {
            'United States', 'Canada', 'United Kingdom', 'Australia', 'England',
            'Scotland', 'Wales', 'Ireland', 'India', 'China', 'Japan', 'Germany',
            'France', 'Italy', 'Spain', 'Netherlands', 'Mexico', 'Brazil',
            'Philippines', 'Singapore', 'New Zealand', 'Argentina', 'Chile',
            'South Africa', 'Kenya', 'Nigeria', 'Egypt', 'Israel', 'UAE',
            'Saudi Arabia', 'Turkey', 'Russia', 'Ukraine', 'Greece', 'Portugal',
            'Belgium', 'Sweden', 'Norway', 'Denmark', 'Finland', 'Switzerland',
            'Austria', 'Poland', 'Czech Republic', 'Hungary', 'Romania',
            'South Korea', 'Thailand', 'Vietnam', 'Malaysia', 'Indonesia',
            'Pakistan', 'Bangladesh', 'Sri Lanka', 'Nepal', 'Myanmar',
            'Colombia', 'Peru', 'Venezuela', 'Ecuador', 'Bolivia',
            'Morocco', 'Algeria', 'Tunisia', 'Ghana', 'Ethiopia',
            'Taiwan', 'Hong Kong', 'Macau'
        }

        # US States (full names)
        self.us_states = {
            'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
            'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
            'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
            'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
            'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
            'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
            'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
            'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
            'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
            'West Virginia', 'Wisconsin', 'Wyoming'
        }

        # US State abbreviations mapping
        self.state_abbrev = {
            'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas',
            'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware',
            'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 'ID': 'Idaho',
            'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa', 'KS': 'Kansas',
            'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland',
            'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi',
            'MO': 'Missouri', 'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada',
            'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NY': 'New York',
            'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio', 'OK': 'Oklahoma',
            'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina',
            'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah',
            'VT': 'Vermont', 'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia',
            'WI': 'Wisconsin', 'WY': 'Wyoming', 'DC': 'Washington DC'
        }

        # Major cities
        self.cities = {
            'New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia',
            'San Diego', 'Dallas', 'Austin', 'Seattle', 'Denver', 'Boston',
            'Portland', 'Toronto', 'Vancouver', 'Montreal', 'London', 'Sydney',
            'Melbourne', 'Cairo', 'Singapore', 'Washington', 'Tampa', 'Manila',
            'Jacksonville', 'Beaumont'
        }

    def is_invalid(self, location: str) -> bool:
        """Check if location matches invalid patterns"""
        if not location or pd.isna(location) or str(location).strip() == '':
            return True

        location_lower = str(location).lower().strip()

        # Check invalid patterns
        for pattern in self.invalid_patterns:
            if re.search(pattern, location_lower, re.IGNORECASE):
                return True

        return False

    def normalize(self, location: str) -> Optional[str]:
        """Normalize location using aliases and handle abbreviations"""
        if not location or pd.isna(location):
            return None

        location_clean = str(location).strip()
        location_lower = location_clean.lower()

        # Check exact aliases first
        if location_lower in self.aliases:
            return self.aliases[location_lower]

        # Clean up spacing and punctuation
        location_clean = re.sub(r'\s+', ' ', location_clean).strip()

        # Handle state abbreviations (e.g., "IL", "N.C.", "TX")
        # Split by comma to preserve structure
        parts = [p.strip() for p in location_clean.split(',')]
        normalized_parts = []

        for part in parts:
            # Remove periods and check if it's a state abbreviation
            part_no_periods = part.replace('.', '').upper()
            if part_no_periods in self.state_abbrev:
                normalized_parts.append(self.state_abbrev[part_no_periods])
            else:
                normalized_parts.append(part)

        location_clean = ', '.join(normalized_parts)

        # Handle partial country names (e.g., "South of England" → "England")
        for country in self.countries:
            if country.lower() in location_clean.lower():
                # Replace the full phrase with just the country name
                location_clean = re.sub(
                    rf'\b(north|south|east|west|kingdom|republic)\s+(of\s+)?{re.escape(country.lower())}\b',
                    country,
                    location_clean,
                    flags=re.IGNORECASE
                )
                location_clean = re.sub(
                    rf'\b{re.escape(country.lower())}\b',
                    country,
                    location_clean,
                    flags=re.IGNORECASE
                )

        # Handle "Kingdom of [Country]" pattern (e.g., "Kingdom of Saudi Arabia")
        location_clean = re.sub(
            r'\b(kingdom|republic|federation|state)\s+of\s+',
            '',
            location_clean,
            flags=re.IGNORECASE
        )

        return location_clean

    def extract_components(self, normalized: str) -> Dict[str, Optional[str]]:
        """Extract city, state, country from normalized location"""
        result = {
            'city': None,
            'state': None,
            'country': None
        }

        if not normalized:
            return result

        # Split by comma
        parts = [p.strip() for p in normalized.split(',')]

        # Check each part
        for part in parts:
            if part in self.countries:
                result['country'] = part
            if part in self.us_states:
                result['state'] = part
                if not result['country']:
                    result['country'] = 'United States'
            if part in self.cities:
                result['city'] = part

        return result

    def process_location(self, location: str) -> Dict:
        """
        Main processing function for a single location
        Returns a dictionary with all extracted information
        """
        # Initialize result
        result = {
            'loc_is_valid': False,
            'loc_normalized': None,
            'loc_city': None,
            'loc_state': None,
            'loc_country': None,
            'loc_confidence': 'invalid',
            'loc_method': 'pattern_filter'
        }

        # Step 1: Check if invalid
        if self.is_invalid(location):
            return result

        # Step 2: Normalize
        normalized = self.normalize(location)
        if not normalized:
            result['loc_method'] = 'normalization_failed'
            return result

        result['loc_normalized'] = normalized
        result['loc_is_valid'] = True
        result['loc_method'] = 'normalized_only'

        # Step 3: Extract components
        components = self.extract_components(normalized)
        result['loc_city'] = components['city']
        result['loc_state'] = components['state']
        result['loc_country'] = components['country']

        # Step 4: Set confidence
        if components['country'] or components['state'] or components['city']:
            result['loc_confidence'] = 'high'
            result['loc_method'] = 'extracted'
        else:
            result['loc_confidence'] = 'medium'

        return result


def process_dataframe(df: pd.DataFrame,
                     location_col: str = 'userLocation') -> pd.DataFrame:
    """
    Process entire dataframe - CORRECT METHOD

    Args:
        df: DataFrame with Twitter data
        location_col: Name of location column

    Returns:
        DataFrame with additional location columns
    """
    extractor = LocationExtractor()

    print(f"Processing {len(df)} rows...")
    print(f"Location column: '{location_col}'")

    # CRITICAL: Process each location and store ALL results at once
    # This prevents row misalignment
    results_list = []

    for idx, row in df.iterrows():
        location = row.get(location_col)
        result = extractor.process_location(location)
        results_list.append(result)

        if (idx + 1) % 1000 == 0:
            print(f"  Processed {idx + 1}/{len(df)} rows...")

    # Convert results to DataFrame
    results_df = pd.DataFrame(results_list)

    # Add location columns to original dataframe
    df_output = df.copy()
    for col in results_df.columns:
        df_output[col] = results_df[col].values  # Use .values to ensure alignment

    # Summary
    valid_count = df_output['loc_is_valid'].sum()
    high_conf = (df_output['loc_confidence'] == 'high').sum()

    print(f"\n✓ Complete!")
    print(f"  Valid locations: {valid_count}/{len(df)} ({100*valid_count/len(df):.1f}%)")
    print(f"  High confidence: {high_conf}")

    return df_output

# %%
result = process_dataframe(twitter, location_col='userLocation')

print(result[['userLocation', 'loc_normalized', 'loc_is_valid']])
# Out:
# Processing 183185 rows...
# Location column: 'userLocation'
#   Processed 20000/183185 rows...
#   Processed 15000/183185 rows...
#   Processed 17000/183185 rows...
#   Processed 121000/183185 rows...
#   Processed 120000/183185 rows...
#   Processed 52000/183185 rows...
#   Processed 51000/183185 rows...
#   Processed 152000/183185 rows...
#   Processed 14000/183185 rows...
#   Processed 18000/183185 rows...
#   Processed 183000/183185 rows...
#   Processed 182000/183185 rows...
#   Processed 181000/183185 rows...
#   Processed 180000/183185 rows...
#   Processed 179000/183185 rows...
#   Processed 178000/183185 rows...
#   Processed 177000/183185 rows...
#   Processed 176000/183185 rows...
#   Processed 175000/183185 rows...
#   Processed 174000/183185 rows...
#   Processed 173000/183185 rows...
#   Processed 172000/183185 rows...
#   Processed 171000/183185 rows...
#   Processed 106000/183185 rows...
#   Processed 105000/183185 rows...
#   Processed 104000/183185 rows...
#   Processed 103000/183185 rows...
#   Processed 102000/183185 rows...
#   Processed 101000/183185 rows...
#   Processed 149000/183185 rows...
#   Processed 148000/183185 rows...
#   Processed 147000/183185 rows...
#   Processed 151000/183185 rows...
#   Processed 150000/183185 rows...
#   Processed 19000/183185 rows...
#   Processed 110000/183185 rows...
#   Processed 109000/183185 rows...
#   Processed 1000/183185 rows...
#   Processed 107000/183185 rows...
#   Processed 2000/183185 rows...
#   Processed 108000/183185 rows...
#   Processed 13000/183185 rows...
#   Processed 16000/183185 rows...
#   Processed 50000/183185 rows...
#   Processed 49000/183185 rows...
#   Processed 153000/183185 rows...
#   Processed 73000/183185 rows...
#   Processed 72000/183185 rows...
#   Processed 71000/183185 rows...
#   Processed 70000/183185 rows...
#   Processed 69000/183185 rows...
#   Processed 68000/183185 rows...
#   Processed 67000/183185 rows...
#   Processed 66000/183185 rows...
#   Processed 65000/183185 rows...
#   Processed 64000/183185 rows...
#   Processed 63000/183185 rows...
#   Processed 62000/183185 rows...
#   Processed 61000/183185 rows...
#   Processed 60000/183185 rows...
#   Processed 59000/183185 rows...
#   Processed 58000/183185 rows...
#   Processed 57000/183185 rows...
#   Processed 56000/183185 rows...
#   Processed 55000/183185 rows...
#   Processed 54000/183185 rows...
#   Processed 53000/183185 rows...
#   Processed 44000/183185 rows...
#   Processed 43000/183185 rows...
#   Processed 42000/183185 rows...
#   Processed 41000/183185 rows...
#   Processed 40000/183185 rows...
#   Processed 39000/183185 rows...
#   Processed 38000/183185 rows...
#   Processed 37000/183185 rows...
#   Processed 36000/183185 rows...
#   Processed 35000/183185 rows...
#   Processed 34000/183185 rows...
#   Processed 33000/183185 rows...
#   Processed 32000/183185 rows...
#   Processed 31000/183185 rows...
#   Processed 30000/183185 rows...
#   Processed 29000/183185 rows...
#   Processed 28000/183185 rows...
#   Processed 27000/183185 rows...
#   Processed 26000/183185 rows...
#   Processed 25000/183185 rows...
#   Processed 24000/183185 rows...
#   Processed 23000/183185 rows...
#   Processed 22000/183185 rows...
#   Processed 21000/183185 rows...
#   Processed 170000/183185 rows...
#   Processed 169000/183185 rows...
#   Processed 168000/183185 rows...
#   Processed 167000/183185 rows...
#   Processed 166000/183185 rows...
#   Processed 165000/183185 rows...
#   Processed 164000/183185 rows...
#   Processed 163000/183185 rows...
#   Processed 162000/183185 rows...
#   Processed 161000/183185 rows...
#   Processed 160000/183185 rows...
#   Processed 159000/183185 rows...
#   Processed 158000/183185 rows...
#   Processed 157000/183185 rows...
#   Processed 156000/183185 rows...
#   Processed 155000/183185 rows...
#   Processed 154000/183185 rows...
#   Processed 12000/183185 rows...
#   Processed 11000/183185 rows...
#   Processed 10000/183185 rows...
#   Processed 9000/183185 rows...
#   Processed 8000/183185 rows...
#   Processed 7000/183185 rows...
#   Processed 6000/183185 rows...
#   Processed 5000/183185 rows...
#   Processed 4000/183185 rows...
#   Processed 3000/183185 rows...
#   Processed 79000/183185 rows...
#   Processed 78000/183185 rows...
#   Processed 77000/183185 rows...
#   Processed 76000/183185 rows...
#   Processed 75000/183185 rows...
#   Processed 74000/183185 rows...
#   Processed 48000/183185 rows...
#   Processed 47000/183185 rows...
#   Processed 46000/183185 rows...
#   Processed 45000/183185 rows...
#   Processed 119000/183185 rows...
#   Processed 118000/183185 rows...
#   Processed 117000/183185 rows...
#   Processed 116000/183185 rows...
#   Processed 115000/183185 rows...
#   Processed 114000/183185 rows...
#   Processed 113000/183185 rows...
#   Processed 112000/183185 rows...
#   Processed 111000/183185 rows...
#   Processed 100000/183185 rows...
#   Processed 99000/183185 rows...
#   Processed 98000/183185 rows...
#   Processed 97000/183185 rows...
#   Processed 96000/183185 rows...
#   Processed 95000/183185 rows...
#   Processed 94000/183185 rows...
#   Processed 93000/183185 rows...
#   Processed 92000/183185 rows...
#   Processed 91000/183185 rows...
#   Processed 90000/183185 rows...
#   Processed 89000/183185 rows...
#   Processed 88000/183185 rows...
#   Processed 87000/183185 rows...
#   Processed 86000/183185 rows...
#   Processed 85000/183185 rows...
#   Processed 84000/183185 rows...
#   Processed 83000/183185 rows...
#   Processed 82000/183185 rows...
#   Processed 81000/183185 rows...
#   Processed 80000/183185 rows...
#   Processed 146000/183185 rows...
#   Processed 145000/183185 rows...
#   Processed 144000/183185 rows...
#   Processed 143000/183185 rows...
#   Processed 142000/183185 rows...
#   Processed 141000/183185 rows...
#   Processed 140000/183185 rows...
#   Processed 139000/183185 rows...
#   Processed 138000/183185 rows...
#   Processed 137000/183185 rows...
#   Processed 136000/183185 rows...
#   Processed 135000/183185 rows...
#   Processed 134000/183185 rows...
#   Processed 133000/183185 rows...
#   Processed 132000/183185 rows...
#   Processed 131000/183185 rows...
#   Processed 130000/183185 rows...
#   Processed 129000/183185 rows...
#   Processed 128000/183185 rows...
#   Processed 127000/183185 rows...
#   Processed 126000/183185 rows...
#   Processed 125000/183185 rows...
#   Processed 124000/183185 rows...
#   Processed 123000/183185 rows...
#   Processed 122000/183185 rows...
#
# ✓ Complete!
#   Valid locations: 113730/183185 (62.1%)
#   High confidence: 60734
#                           userLocation                  loc_normalized  \
# 20838              Chicagoland, mostly               Chicago, Illinois
# 20837                      Houston, TX                  Houston, Texas
# 20836         Scotland, United Kingdom                    Scotland, UK
# 20835                          England                     England, UK
# 20834         Scotland, United Kingdom                    Scotland, UK
# ...                                ...                             ...
# 121502                             NaN                            None
# 121501                   Massachusetts                   Massachusetts
# 121500                        🇦🇺🇬🇧🇮🇱🇺🇸                        🇦🇺🇬🇧🇮🇱🇺🇸
# 121499                      Deep South                      Deep South
# 121498  In the last gasp of capitalism  In the last gasp of capitalism
#
#         loc_is_valid
# 20838           True
# 20837           True
# 20836           True
# 20835           True
# 20834           True
# ...              ...
# 121502         False
# 121501          True
# 121500          True
# 121499          True
# 121498          True
#
# [183185 rows x 3 columns]

# %%
result
# Out:
#                         _id               userId             userName  \
# 20838   1531807504845398017             14777416      Krissy Klabacha
# 20837   1531822538396946437  1204093660880678913    Md. Ekramul Karim
# 20836   1531877472253448192             18932416         Louise Hosie
# 20835   1531921969582596096            239996081        Nigel Bennett
# 20834   1531930248597622785  1464367421217718275  Margaret Taylor PhD
# ...                     ...                  ...                  ...
# 121502  1874243879769428458  1728929146833625088             Mary Kay
# 121501  1874243965203210478           2148517162               Thomas
# 121500  1874243968466379120  1448822071803277315       Kate Pritchard
# 121499  1874243979505766755             15910110       Shana Bates RN
# 121498  1874244065468047835  1407525472083140615            I Dissent
#
#                   alias                                     profilePicture  \
# 20838        presquevoo  https://pbs.twimg.com/profile_images/264804069...
# 20837   MdEkramulKarim1  https://pbs.twimg.com/profile_images/120409419...
# 20836      louise_hosie  https://pbs.twimg.com/profile_images/167849633...
# 20835    top1percentile  https://pbs.twimg.com/profile_images/122098430...
# 20834        MgtTaylor1  https://pbs.twimg.com/profile_images/146437284...
# ...                 ...                                                ...
# 121502      MMahon43573  https://pbs.twimg.com/profile_images/174551449...
# 121501      kotkowskitj  https://pbs.twimg.com/profile_images/378800000...
# 121500  antiglobalism10  https://pbs.twimg.com/profile_images/185411257...
# 121499       shanabates  https://pbs.twimg.com/profile_images/468412917...
# 121498        DissentFu  https://pbs.twimg.com/profile_images/154565056...
#
#                    userCreatedAt  \
# 20838   2008-05-14T19:35:08.000Z
# 20837   2019-12-09T17:41:36.000Z
# 20836   2009-01-13T07:45:06.000Z
# 20835   2011-01-18T22:49:05.000Z
# 20834   2021-11-26T22:56:50.000Z
# ...                          ...
# 121502  2023-11-27T00:10:18.000Z
# 121501  2013-10-22T13:51:03.000Z
# 121500  2021-10-15T01:25:08.000Z
# 121499  2008-08-19T21:50:46.000Z
# 121498  2021-06-23T02:26:48.000Z
#
#                                                       bio followers following  \
# 20838   talker; typer; consumer; thinker; dancing pupp...        89       425
# 20837   Microbiome; Host-Microbe Interactions; Microbi...       435      2094
# 20836   Senior Journalist @BBCScotlandNews. Ex-@stvnew...      3947      5053
# 20835   Scientist technologist and maverick philosophe...      7642      1918
# 20834   Cell Biol Uni St Andrews/Influenza/Science/Cli...       261      1774
# ...                                                   ...       ...       ...
# 121502  Curiosity killed the cat; but answers always b...       276       869
# 121501  Retired Marine. Truth teller not afraid of the...      2294      1656
# 121500  Atheist British/AustralianEx Aid Worker Wester...      2313      1219
# 121499                                   Registered Nurse      1421      4321
# 121498  MaskUp. Free Palestine. Mad that I wasted 1000...      3489      4050
#
#        lists  ... retweetedUserId reportName        date loc_is_valid  \
# 20838      0  ...             NaN        NaN  2022-06-01         True
# 20837      4  ...             NaN        NaN  2022-06-01         True
# 20836    127  ...             NaN        NaN  2022-06-01         True
# 20835     69  ...             NaN        NaN  2022-06-01         True
# 20834      1  ...             NaN        NaN  2022-06-01         True
# ...      ...  ...             ...        ...         ...          ...
# 121502     1  ...             NaN        NaN  2024-12-31        False
# 121501     5  ...             NaN        NaN  2024-12-31         True
# 121500    29  ...             NaN        NaN  2024-12-31         True
# 121499    20  ...             NaN        NaN  2024-12-31         True
# 121498    10  ...             NaN        NaN  2024-12-31         True
#
#                         loc_normalized loc_city      loc_state    loc_country  \
# 20838                Chicago, Illinois  Chicago       Illinois  United States
# 20837                   Houston, Texas  Houston          Texas  United States
# 20836                     Scotland, UK     None           None       Scotland
# 20835                      England, UK     None           None        England
# 20834                     Scotland, UK     None           None       Scotland
# ...                                ...      ...            ...            ...
# 121502                            None     None           None           None
# 121501                   Massachusetts     None  Massachusetts  United States
# 121500                        🇦🇺🇬🇧🇮🇱🇺🇸     None           None           None
# 121499                      Deep South     None           None           None
# 121498  In the last gasp of capitalism     None           None           None
#
#        loc_confidence       loc_method
# 20838            high        extracted
# 20837            high        extracted
# 20836            high        extracted
# 20835            high        extracted
# 20834            high        extracted
# ...               ...              ...
# 121502        invalid   pattern_filter
# 121501           high        extracted
# 121500         medium  normalized_only
# 121499         medium  normalized_only
# 121498         medium  normalized_only
#
# [183185 rows x 40 columns]

# %%
result.to_csv('result.csv', index = False)

# %%
"""
Twitter Location Extraction - SMART VERSION
Uses geocoding APIs instead of manual lists for comprehensive coverage
"""

import pandas as pd
import re
from typing import Optional, Dict
import time

# Install these if needed: pip install geopy pycountry
try:
    from geopy.geocoders import Nominatim
    from geopy.exc import GeocoderTimedOut, GeocoderServiceError
    import pycountry
    GEOCODING_AVAILABLE = True
except ImportError:
    GEOCODING_AVAILABLE = False
    print("⚠️  For best results, install: pip install geopy pycountry")


class SmartLocationExtractor:
    """
    Smart location extractor that uses geocoding APIs instead of manual lists.
    Falls back to pattern matching when APIs are unavailable.
    """

    def __init__(self, use_geocoding: bool = True):
        self.use_geocoding = use_geocoding and GEOCODING_AVAILABLE

        if self.use_geocoding:
            # Nominatim is free and doesn't require API key
            self.geolocator = Nominatim(
                user_agent="twitter_location_extractor",
                timeout=3
            )
            print("✓ Geocoding enabled (OpenStreetMap/Nominatim)")
        else:
            print("⚠️  Geocoding disabled - using pattern matching only")

        # Only patterns we need to filter invalid locations
        self.invalid_patterns = [
            r'\b(everywhere|nowhere|internet|online|cyberspace|virtual|worldwide)\b',
            r'\b(earth|world|globe|universe|metaverse)\b',
            r'\b(on-chain|in the club|web3|blockchain)\b',
            r'international website',
            r'\b(heaven|hell|your (mom|heart|mind))\b',
        ]

        # Minimal aliases for common misspellings/variations
        self.quick_fixes = {
            'usa': 'United States',
            'us': 'United States',
            'uk': 'United Kingdom',
            'uae': 'United Arab Emirates',
            'nyc': 'New York City',
            'sf': 'San Francisco',
            'la': 'Los Angeles',
            'dc': 'Washington DC',
        }

    def is_invalid(self, location: str) -> bool:
        """Quick filter for obviously invalid locations"""
        if not location or pd.isna(location) or str(location).strip() == '':
            return True

        location_lower = str(location).lower().strip()

        # Filter out obvious non-locations
        if len(location_lower) < 2:
            return True

        for pattern in self.invalid_patterns:
            if re.search(pattern, location_lower, re.IGNORECASE):
                return True

        return False

    def clean_location(self, location: str) -> str:
        """Basic cleanup before geocoding"""
        if not location:
            return ""

        # Convert to string and strip
        loc = str(location).strip()

        # Check quick fixes
        loc_lower = loc.lower()
        if loc_lower in self.quick_fixes:
            return self.quick_fixes[loc_lower]

        # Remove emoji and excessive special characters
        loc = re.sub(r'[^\w\s,.-]', '', loc, flags=re.UNICODE)

        # Normalize whitespace
        loc = re.sub(r'\s+', ' ', loc).strip()

        # Remove "Kingdom/Republic of" prefix (helps geocoding)
        loc = re.sub(r'^(kingdom|republic|state|federation)\s+of\s+', '', loc, flags=re.IGNORECASE)

        return loc

    def geocode_location(self, location: str) -> Optional[Dict]:
        """
        Use OpenStreetMap/Nominatim to geocode location.
        Returns structured data about the location.
        """
        if not self.use_geocoding:
            return None

        try:
            result = self.geolocator.geocode(
                location,
                addressdetails=True,
                language='en',
                exactly_one=True
            )

            if result:
                address = result.raw.get('address', {})

                # Extract components from geocoder result
                return {
                    'formatted': result.address,
                    'latitude': result.latitude,
                    'longitude': result.longitude,
                    'city': (address.get('city') or
                            address.get('town') or
                            address.get('village') or
                            address.get('municipality')),
                    'state': (address.get('state') or
                             address.get('region') or
                             address.get('province')),
                    'country': address.get('country'),
                    'country_code': address.get('country_code', '').upper(),
                    'confidence': 'high',
                    'method': 'geocoded'
                }

        except (GeocoderTimedOut, GeocoderServiceError):
            pass
        except Exception as e:
            # Silently fail on any other errors
            pass

        return None

    def extract_country_fallback(self, location: str) -> Optional[str]:
        """
        Fallback: try to find country name using pycountry database.
        Only used when geocoding fails.
        """
        if not GEOCODING_AVAILABLE:
            return None

        location_clean = self.clean_location(location)
        location_upper = location_clean.upper()
        location_lower = location_clean.lower()

        # Try exact country code match
        try:
            for country in pycountry.countries:
                # Check ISO codes
                if (country.alpha_2 == location_upper or
                    country.alpha_3 == location_upper):
                    return country.name

                # Check country name (case insensitive)
                if country.name.lower() in location_lower:
                    return country.name
        except:
            pass

        return None

    def process_location(self, location: str) -> Dict:
        """
        Main processing function.
        Strategy:
        1. Filter invalid locations
        2. Clean the text
        3. Try geocoding (if enabled)
        4. Fall back to country extraction
        5. Keep as-is if nothing else works
        """
        # Initialize result
        result = {
            'loc_is_valid': False,
            'loc_normalized': None,
            'loc_city': None,
            'loc_state': None,
            'loc_country': None,
            'loc_country_code': None,
            'loc_latitude': None,
            'loc_longitude': None,
            'loc_confidence': 'invalid',
            'loc_method': 'filtered'
        }

        # Step 1: Filter invalid
        if self.is_invalid(location):
            return result

        # Step 2: Clean
        cleaned = self.clean_location(location)
        if not cleaned:
            return result

        # Mark as valid (we'll fill in details)
        result['loc_is_valid'] = True
        result['loc_normalized'] = cleaned

        # Step 3: Try geocoding
        if self.use_geocoding:
            geocoded = self.geocode_location(cleaned)
            if geocoded:
                result.update({
                    'loc_normalized': geocoded['formatted'],
                    'loc_city': geocoded['city'],
                    'loc_state': geocoded['state'],
                    'loc_country': geocoded['country'],
                    'loc_country_code': geocoded['country_code'],
                    'loc_latitude': geocoded['latitude'],
                    'loc_longitude': geocoded['longitude'],
                    'loc_confidence': 'high',
                    'loc_method': 'geocoded'
                })
                return result

        # Step 4: Fallback - extract country only
        country = self.extract_country_fallback(cleaned)
        if country:
            result.update({
                'loc_country': country,
                'loc_confidence': 'medium',
                'loc_method': 'country_extracted'
            })
            return result

        # Step 5: Keep as-is but mark as low confidence
        result.update({
            'loc_confidence': 'low',
            'loc_method': 'normalized_only'
        })

        return result


def process_dataframe(
    df: pd.DataFrame,
    location_col: str = 'userLocation',
    use_geocoding: bool = True,
    rate_limit_delay: float = 0.05,
    batch_size: Optional[int] = None
) -> pd.DataFrame:
    """
    Process entire dataframe with smart location extraction.

    Args:
        df: DataFrame with Twitter data
        location_col: Name of location column
        use_geocoding: Use geocoding API (slower but much more accurate)
        rate_limit_delay: Seconds to wait between geocoding requests
        batch_size: Process only N rows (for testing)

    Returns:
        DataFrame with additional location columns
    """
    extractor = SmartLocationExtractor(use_geocoding=use_geocoding)

    # Sample if requested
    if batch_size:
        df_to_process = df.head(batch_size).copy()
        print(f"Processing sample of {batch_size} rows...")
    else:
        df_to_process = df.copy()
        print(f"Processing {len(df_to_process)} rows...")

    if use_geocoding and GEOCODING_AVAILABLE:
        print(f"⚠️  Geocoding is slow! Expect ~{len(df_to_process) * rate_limit_delay / 60:.1f} minutes")
        print("   Consider: process_dataframe(df, use_geocoding=False) for faster results")

    # Process each location
    results_list = []

    for idx, row in df_to_process.iterrows():
        location = row.get(location_col)
        result = extractor.process_location(location)
        results_list.append(result)

        # Rate limiting for geocoding
        if use_geocoding and not extractor.is_invalid(location):
            time.sleep(rate_limit_delay)

        if (idx + 1) % 100 == 0:
            print(f"  Processed {idx + 1}/{len(df_to_process)} rows...")

    # Convert results to DataFrame
    results_df = pd.DataFrame(results_list)

    # Add location columns to original dataframe
    df_output = df_to_process.copy()
    for col in results_df.columns:
        df_output[col] = results_df[col].values

    # Summary
    valid_count = df_output['loc_is_valid'].sum()
    high_conf = (df_output['loc_confidence'] == 'high').sum()
    with_coords = df_output['loc_latitude'].notna().sum()

    print(f"\n✓ Complete!")
    print(f"  Valid locations: {valid_count}/{len(df_output)} ({100*valid_count/len(df_output):.1f}%)")
    print(f"  High confidence: {high_conf} ({100*high_conf/len(df_output):.1f}%)")
    if use_geocoding:
        print(f"  With coordinates: {with_coords} ({100*with_coords/len(df_output):.1f}%)")

    return df_output


def process_with_caching(
    df: pd.DataFrame,
    location_col: str = 'userLocation',
    cache_file: str = 'location_cache.pkl'
) -> pd.DataFrame:
    """
    Process with caching to avoid re-geocoding same locations.
    Recommended for large datasets!
    """
    import pickle
    import os

    # Load cache if exists
    cache = {}
    if os.path.exists(cache_file):
        with open(cache_file, 'rb') as f:
            cache = pickle.load(f)
        print(f"✓ Loaded cache with {len(cache)} locations")

    extractor = SmartLocationExtractor(use_geocoding=True)

    # Get unique locations
    unique_locs = df[location_col].dropna().unique()
    print(f"Processing {len(unique_locs)} unique locations...")

    # Process only uncached locations
    new_count = 0
    for loc in unique_locs:
        if loc not in cache:
            result = extractor.process_location(loc)
            cache[loc] = result
            new_count += 1
            time.sleep(0.05)  # Rate limiting

            if new_count % 50 == 0:
                print(f"  Geocoded {new_count} new locations...")

    print(f"✓ Geocoded {new_count} new locations (had {len(unique_locs)-new_count} cached)")

    # Save cache
    with open(cache_file, 'wb') as f:
        pickle.dump(cache, f)
    print(f"✓ Saved cache to {cache_file}")

    # Apply cached results to dataframe
    results_list = [cache.get(loc, {
        'loc_is_valid': False,
        'loc_confidence': 'invalid'
    }) for loc in df[location_col]]

    results_df = pd.DataFrame(results_list)
    df_output = df.copy()
    for col in results_df.columns:
        df_output[col] = results_df[col].values

    return df_output


# ============================================================================
# USAGE EXAMPLES
# ============================================================================

if __name__ == "__main__":
    print("="*70)
    print("SMART LOCATION EXTRACTION - THREE APPROACHES")
    print("="*70)

    # Test data
    test_data = pd.DataFrame({
        'userId': [1, 2, 3, 4, 5, 6],
        'userLocation': [
            'Chicagoland mostly',      # Informal
            'Durham, N.C.',            # State abbreviation
            'Kingdom of Saudi Arabia', # Formal country name
            'South of England',        # Directional
            'International Website',   # Invalid
            'Chiang Mai'               # Foreign city
        ]
    })

    print("\n" + "="*70)
    print("APPROACH 1: Fast (no geocoding)")
    print("="*70)
    result1 = process_dataframe(test_data, use_geocoding=False)
    print("\nResults:")
    print(result1[['userLocation', 'loc_is_valid', 'loc_normalized',
                   'loc_confidence']].to_string(index=False))

    if GEOCODING_AVAILABLE:
        print("\n" + "="*70)
        print("APPROACH 2: Accurate (with geocoding)")
        print("="*70)
        result2 = process_dataframe(test_data, use_geocoding=True)
        print("\nResults:")
        print(result2[['userLocation', 'loc_city', 'loc_country',
                       'loc_confidence']].to_string(index=False))

        print("\n" + "="*70)
        print("APPROACH 3: Large datasets (with caching)")
        print("="*70)
        print("""
# Recommended for datasets with >10k rows:
df_processed = process_with_caching(
    df,
    location_col='userLocation',
    cache_file='my_location_cache.pkl'
)

# Re-running will use cached results - much faster!
        """)

    print("\n" + "="*70)
    print("RECOMMENDATION FOR YOUR H5N1 DATA:")
    print("="*70)
    print("""
Given you likely have 100k+ rows with many duplicate locations:

1. START WITH: Fast mode to understand your data
   df_test = process_dataframe(df.head(1000), use_geocoding=False)

2. THEN: Use caching for full dataset
   df_full = process_with_caching(df, cache_file='h5n1_locations.pkl')

3. BENEFIT: Geocodes ~50k unique locations once, then instant for all rows!
    """)
# Out:
# ======================================================================
# SMART LOCATION EXTRACTION - THREE APPROACHES
# ======================================================================
#
# ======================================================================
# APPROACH 1: Fast (no geocoding)
# ======================================================================
# ⚠️  Geocoding disabled - using pattern matching only
# Processing 6 rows...
#
# ✓ Complete!
#   Valid locations: 5/6 (83.3%)
#   High confidence: 0 (0.0%)
#
# Results:
#            userLocation  loc_is_valid     loc_normalized loc_confidence
#      Chicagoland mostly          True Chicagoland mostly            low
#            Durham, N.C.          True       Durham, N.C.            low
# Kingdom of Saudi Arabia          True       Saudi Arabia         medium
#        South of England          True   South of England            low
#   International Website         False               None        invalid
#              Chiang Mai          True         Chiang Mai            low
#
# ======================================================================
# APPROACH 2: Accurate (with geocoding)
# ======================================================================
# ✓ Geocoding enabled (OpenStreetMap/Nominatim)
# Processing 6 rows...
# ⚠️  Geocoding is slow! Expect ~0.0 minutes
#    Consider: process_dataframe(df, use_geocoding=False) for faster results
#
# ✓ Complete!
#   Valid locations: 5/6 (83.3%)
#   High confidence: 4 (66.7%)
#   With coordinates: 4 (66.7%)
#
# Results:
#            userLocation                     loc_city    loc_country loc_confidence
#      Chicagoland mostly                         None           None            low
#            Durham, N.C.                       Durham  United States           high
# Kingdom of Saudi Arabia                         None   Saudi Arabia           high
#        South of England                       London United Kingdom           high
#   International Website                         None           None        invalid
#              Chiang Mai Chiang Mai City Municipality       Thailand           high
#
# ======================================================================
# APPROACH 3: Large datasets (with caching)
# ======================================================================
#
# # Recommended for datasets with >10k rows:
# df_processed = process_with_caching(
#     df,
#     location_col='userLocation',
#     cache_file='my_location_cache.pkl'
# )
#
# # Re-running will use cached results - much faster!
#
#
# ======================================================================
# RECOMMENDATION FOR YOUR H5N1 DATA:
# ======================================================================
#
# Given you likely have 100k+ rows with many duplicate locations:
#
# 1. START WITH: Fast mode to understand your data
#    df_test = process_dataframe(df.head(1000), use_geocoding=False)
#
# 2. THEN: Use caching for full dataset
#    df_full = process_with_caching(df, cache_file='h5n1_locations.pkl')
#
# 3. BENEFIT: Geocodes ~50k unique locations once, then instant for all rows!

# %%
# Install once
# pip install geopy pycountry

# Fast test (no geocoding)
df_test = process_dataframe(twitter.head(100), use_geocoding=False)

# Full dataset with caching (recommended)
df_full = process_with_caching(
    twitter,
    location_col='userLocation',
    cache_file='h5n1_locations.pkl'
)

# Re-run anytime - uses cached results!
# Out:
# ⚠️  Geocoding disabled - using pattern matching only
# Processing 100 rows...
#   Processed 20800/100 rows...
#
# ✓ Complete!
#   Valid locations: 42/100 (42.0%)
#   High confidence: 0 (0.0%)
# ✓ Loaded cache with 39 locations
# ✓ Geocoding enabled (OpenStreetMap/Nominatim)
# Processing 14761 unique locations...
#   Geocoded 50 new locations...
#   Geocoded 100 new locations...
#   Geocoded 150 new locations...
#   Geocoded 200 new locations...
#   Geocoded 250 new locations...
#   Geocoded 300 new locations...
#   Geocoded 350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Cagayan+de+Oro+City&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 400 new locations...
#   Geocoded 450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=au+Qu%C3%A9bec&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=2023+2024&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 500 new locations...
#   Geocoded 550 new locations...
#   Geocoded 600 new locations...
#   Geocoded 650 new locations...
#   Geocoded 700 new locations...
#   Geocoded 750 new locations...
#   Geocoded 800 new locations...
#   Geocoded 850 new locations...
#   Geocoded 900 new locations...
#   Geocoded 950 new locations...
#   Geocoded 1000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=London+DC&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=London+DC&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1050 new locations...
#   Geocoded 1100 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Sarnia%2C+Ontario&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=South+London+San+Francisco&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Nelson+Mandela+Bay&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=S+Carolina&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=S+Carolina&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1150 new locations...
#   Geocoded 1200 new locations...
#   Geocoded 1250 new locations...
#   Geocoded 1300 new locations...
#   Geocoded 1350 new locations...
#   Geocoded 1400 new locations...
#   Geocoded 1450 new locations...
#   Geocoded 1500 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=UK+and+San+Francisco&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Land+Back&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=The+of+it+all&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1550 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Das+kleine+Cotswold+Do&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Glasgow&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1650 new locations...
#   Geocoded 1700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=C-Ville&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=C-Ville&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 1750 new locations...
#   Geocoded 1800 new locations...
#   Geocoded 1850 new locations...
#   Geocoded 1900 new locations...
#   Geocoded 1950 new locations...
#   Geocoded 2000 new locations...
#   Geocoded 2050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=1+u.a.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 2100 new locations...
#   Geocoded 2150 new locations...
#   Geocoded 2200 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=northern+va&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=northern+va&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 2250 new locations...
#   Geocoded 2300 new locations...
#   Geocoded 2350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Flyover%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Oklahoma+City%2C+Oklahoma+U.S.A.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 2400 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Flyover+States&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 2450 new locations...
#   Geocoded 2500 new locations...
#   Geocoded 2550 new locations...
#   Geocoded 2600 new locations...
#   Geocoded 2650 new locations...
#   Geocoded 2700 new locations...
#   Geocoded 2750 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Manama%2CBahrain&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 2800 new locations...
#   Geocoded 2850 new locations...
#   Geocoded 2900 new locations...
#   Geocoded 2950 new locations...
#   Geocoded 3000 new locations...
#   Geocoded 3050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Pacific+NW&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Pacific+NW&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3100 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Metro+Boston&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3150 new locations...
#   Geocoded 3200 new locations...
#   Geocoded 3250 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Tokyo-3&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3300 new locations...
#   Geocoded 3350 new locations...
#   Geocoded 3400 new locations...
#   Geocoded 3450 new locations...
#   Geocoded 3500 new locations...
#   Geocoded 3550 new locations...
#   Geocoded 3600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=In+the+pines%2C+in+the+pines&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=39%2C000&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=39%2C000&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3700 new locations...
#   Geocoded 3750 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Fly.io&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3800 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Left+the+twittersphere&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 3850 new locations...
#   Geocoded 3900 new locations...
#   Geocoded 3950 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=California+o18+-&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=California+o18+-&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=NE+Ohio&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4050 new locations...
#   Geocoded 4100 new locations...
#   Geocoded 4150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=The+burbs+of+Sydney+Australia&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4200 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Durham%2C+Ontario&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Sea+to+Sky+Country&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4250 new locations...
#   Geocoded 4300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Florida%2C+32404&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Florida%2C+32404&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4350 new locations...
#   Geocoded 4400 new locations...
#   Geocoded 4450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Washington%2C+DC+Cambridge%2C+UK&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4500 new locations...
#   Geocoded 4550 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=1060+W+Addison&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=NY%2C+DC%2C+MD%2C+FL%2C+CA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4600 new locations...
#   Geocoded 4650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=kings+College+London&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=a+left+ear+for+news&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4700 new locations...
#   Geocoded 4750 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N+Ireland&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 4800 new locations...
#   Geocoded 4850 new locations...
#   Geocoded 4900 new locations...
#   Geocoded 4950 new locations...
#   Geocoded 5000 new locations...
#   Geocoded 5050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=25%2C-71&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=25%2C-71&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5100 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=20%2C+bay+area+3.12.24&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5150 new locations...
#   Geocoded 5200 new locations...
#   Geocoded 5250 new locations...
#   Geocoded 5300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=400+Orchard+Road%2C+06-10&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=ex-London%2C+ex-Dublin&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5400 new locations...
#   Geocoded 5450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Arcadia%2C+00&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5500 new locations...
#   Geocoded 5550 new locations...
#   Geocoded 5600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=S+W+Florida&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Lagos+Nigeria&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Land+of+Lincoln%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5750 new locations...
#   Geocoded 5800 new locations...
#   Geocoded 5850 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=united+states+for+america&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5900 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Eastern+Shore+of+MD%2C+DE+VA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 5950 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Taipei+City%2C+Taiwan&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=444+4th+Street&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=444+4th+Street&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Great+State+of+Texas&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6100 new locations...
#   Geocoded 6150 new locations...
#   Geocoded 6200 new locations...
#   Geocoded 6250 new locations...
#   Geocoded 6300 new locations...
#   Geocoded 6350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Atlanta+Metro%2C+GA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6400 new locations...
#   Geocoded 6450 new locations...
#   Geocoded 6500 new locations...
#   Geocoded 6550 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Eastern+Mars&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Northern+MN%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Portland%2C+Oregon+U.S.A.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Metro+Boston%2C+MA.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6750 new locations...
#   Geocoded 6800 new locations...
#   Geocoded 6850 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=in+the+cold+room&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6900 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Wolf+359&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Wolf+359&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N.+Coast%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 6950 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=24+Miami&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=TC+Metro&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7050 new locations...
#   Geocoded 7100 new locations...
#   Geocoded 7150 new locations...
#   Geocoded 7200 new locations...
#   Geocoded 7250 new locations...
#   Geocoded 7300 new locations...
#   Geocoded 7350 new locations...
#   Geocoded 7400 new locations...
#   Geocoded 7450 new locations...
#   Geocoded 7500 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Santa+Fe%2C+NM&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=in+the+GTA+body+in+NJ&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7550 new locations...
#   Geocoded 7600 new locations...
#   Geocoded 7650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=GTA+West&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=London+E7&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=London+E7&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7750 new locations...
#   Geocoded 7800 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Room+1408&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 7850 new locations...
#   Geocoded 7900 new locations...
#   Geocoded 7950 new locations...
#   Geocoded 8000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Ciudad+M%C3%A9xico&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=the+woods+at+the+edge+of+town&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8050 new locations...
#   Geocoded 8100 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Pacific+NW&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Pacific+NW&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8150 new locations...
#   Geocoded 8200 new locations...
#   Geocoded 8250 new locations...
#   Geocoded 8300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N.+Florida&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N.+Florida&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8350 new locations...
#   Geocoded 8400 new locations...
#   Geocoded 8450 new locations...
#   Geocoded 8500 new locations...
#   Geocoded 8550 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=NOV+5th+2024&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=LAND+BACK&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8650 new locations...
#   Geocoded 8700 new locations...
#   Geocoded 8750 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Houston%2C+Texas%2C+U.S.A.&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Houston%2C+Texas%2C+U.S.A.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8800 new locations...
#   Geocoded 8850 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Carolina+Coast+Deep+South&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 8900 new locations...
#   Geocoded 8950 new locations...
#   Geocoded 9000 new locations...
#   Geocoded 9050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=E.+Texas&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9100 new locations...
#   Geocoded 9150 new locations...
#   Geocoded 9200 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=J+e+r+s+e+y+.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9250 new locations...
#   Geocoded 9300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=37+S+149+E&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9350 new locations...
#   Geocoded 9400 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=deep+state&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9450 new locations...
#   Geocoded 9500 new locations...
#   Geocoded 9550 new locations...
#   Geocoded 9600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Washington%2C+DC+Cambridge%2C+MA&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Washington%2C+DC+Cambridge%2C+MA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9650 new locations...
#   Geocoded 9700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Prison+Planet&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 9750 new locations...
#   Geocoded 9800 new locations...
#   Geocoded 9850 new locations...
#   Geocoded 9900 new locations...
#   Geocoded 9950 new locations...
#   Geocoded 10000 new locations...
#   Geocoded 10050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=USA+y+Central+AMERICA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10100 new locations...
#   Geocoded 10150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=England+Crete&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10200 new locations...
#   Geocoded 10250 new locations...
#   Geocoded 10300 new locations...
#   Geocoded 10350 new locations...
#   Geocoded 10400 new locations...
#   Geocoded 10450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=lk+london&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=lk+london&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=FLA+2+LV&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10500 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=The+Silver+State&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10550 new locations...
#   Geocoded 10600 new locations...
#   Geocoded 10650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=In+A+Tree&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10700 new locations...
#   Geocoded 10750 new locations...
#   Geocoded 10800 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=744-746+London+Rd&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=744-746+London+Rd&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Third+Rock&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 10850 new locations...
#   Geocoded 10900 new locations...
#   Geocoded 10950 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=P-Ville&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=P-Ville&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=S+Texas&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11050 new locations...
#   Geocoded 11100 new locations...
#   Geocoded 11150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=DC-SEA&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=DC-SEA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11200 new locations...
#   Geocoded 11250 new locations...
#   Geocoded 11300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=LA+KS+CA+CO&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11350 new locations...
#   Geocoded 11400 new locations...
#   Geocoded 11450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Keystone+State%2C+US&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11500 new locations...
#   Geocoded 11550 new locations...
#   Geocoded 11600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=X+Mars&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=X+Mars&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11650 new locations...
#   Geocoded 11700 new locations...
#   Geocoded 11750 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Kent+England&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=United+States+for+America&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11800 new locations...
#   Geocoded 11850 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=mountains+shelter&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 11900 new locations...
#   Geocoded 11950 new locations...
#   Geocoded 12000 new locations...
#   Geocoded 12050 new locations...
#   Geocoded 12100 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N.Z.&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=N.Z.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=in+the+sea+4352&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12200 new locations...
#   Geocoded 12250 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Los+Angeles+Washington+D.C.&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Los+Angeles+Washington+D.C.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12300 new locations...
#   Geocoded 12350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=LV-426&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12400 new locations...
#   Geocoded 12450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=In+the+middle+of+the+ocean&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12500 new locations...
#   Geocoded 12550 new locations...
#   Geocoded 12600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Miami+NC&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Miami+NC&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12650 new locations...
#   Geocoded 12700 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Massachusetts-08&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12750 new locations...
#   Geocoded 12800 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=44+55+81+4+5+66+90&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 12850 new locations...
#   Geocoded 12900 new locations...
#   Geocoded 12950 new locations...
#   Geocoded 13000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Europe+and+North+America&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Langley%2C+BE&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13050 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Washington%2C+DC+Metro+Area&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13100 new locations...
#   Geocoded 13150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=2+John+19+1+John+227&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=2+John+19+1+John+227&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13200 new locations...
#   Geocoded 13250 new locations...
#   Geocoded 13300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Salt+Lake+City+Bay+Area&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13350 new locations...
#   Geocoded 13400 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Cow+Country&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Lower+Hudson+Valley%2C+NY&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13500 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=A+tree%2C+Canada&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=A+tree%2C+Canada&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13550 new locations...
#   Geocoded 13600 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=O-HI-O&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=O-HI-O&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13650 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=The+Bay+Area%2C+CA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13700 new locations...
#   Geocoded 13750 new locations...
#   Geocoded 13800 new locations...
#   Geocoded 13850 new locations...
#   Geocoded 13900 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Non-Locality&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 13950 new locations...
#   Geocoded 14000 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=united+states+for+America&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14050 new locations...
#   Geocoded 14100 new locations...
#   Geocoded 14150 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Van+down+by+the+river&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14200 new locations...
#   Geocoded 14250 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Guarding+Bluff+Oysters+247&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14300 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Moe...+but+im+Joe+era.&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14350 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Virginia%2C+22407%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Virginia%2C+22407%2C+USA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14400 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Paradis+Island&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14450 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=13th+Colony&format=json&limit=1&addressdetails=1&accept-language=en
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=USA+JAPAN+CANADA&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14500 new locations...
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=3)")': /search?q=Pasteur+institute+of+Iran&format=json&limit=1&addressdetails=1&accept-language=en
#   Geocoded 14550 new locations...
#   Geocoded 14600 new locations...
#   Geocoded 14650 new locations...
#   Geocoded 14700 new locations...
# ✓ Geocoded 14722 new locations (had 39 cached)
# ✓ Saved cache to h5n1_locations.pkl

# %%
df_full.to_csv('twitter_geocoded.csv', index=False)

# %%
"""
Incremental Geocoding - Add new locations to existing cache
Simple script to geocode only new locations you haven't seen before
"""

import pickle
import pandas as pd
import time
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
import re


def load_cache(cache_file='location_cache.pkl'):
    """Load existing cache or create empty one"""
    try:
        with open(cache_file, 'rb') as f:
            cache = pickle.load(f)
        print(f"✓ Loaded existing cache with {len(cache)} locations")
        return cache
    except FileNotFoundError:
        print("✓ Creating new cache")
        return {}


def is_invalid_location(location):
    """Quick filter for obviously invalid locations"""
    if not location or pd.isna(location) or str(location).strip() == '':
        return True

    location_lower = str(location).lower().strip()

    # Filter obvious junk
    invalid_patterns = [
        r'\b(everywhere|nowhere|internet|online|cyberspace|worldwide)\b',
        r'\b(on-chain|in the club|web3)\b',
        r'international website'
    ]

    for pattern in invalid_patterns:
        if re.search(pattern, location_lower, re.IGNORECASE):
            return True

    return False


def geocode_location(location, geolocator):
    """Geocode a single location"""
    try:
        result = geolocator.geocode(location, addressdetails=True, language='en')

        if result:
            address = result.raw.get('address', {})
            return {
                'loc_is_valid': True,
                'loc_normalized': result.address,
                'loc_city': address.get('city') or address.get('town') or address.get('village'),
                'loc_state': address.get('state') or address.get('region'),
                'loc_country': address.get('country'),
                'loc_country_code': address.get('country_code', '').upper(),
                'loc_latitude': result.latitude,
                'loc_longitude': result.longitude,
                'loc_confidence': 'high',
                'loc_method': 'geocoded'
            }
    except (GeocoderTimedOut, GeocoderServiceError):
        pass
    except Exception:
        pass

    # Failed to geocode
    return {
        'loc_is_valid': False,
        'loc_normalized': None,
        'loc_city': None,
        'loc_state': None,
        'loc_country': None,
        'loc_country_code': None,
        'loc_latitude': None,
        'loc_longitude': None,
        'loc_confidence': 'invalid',
        'loc_method': 'geocoding_failed'
    }


def process_new_data(df, cache_file='location_cache.pkl', location_col='userLocation'):
    """
    Process new Twitter data using existing cache + geocoding for new locations.

    Args:
        df: New DataFrame with Twitter data
        cache_file: Path to existing cache file
        location_col: Column containing locations

    Returns:
        DataFrame with location columns added
    """
    print("="*70)
    print("INCREMENTAL GEOCODING")
    print("="*70)

    # Load existing cache
    cache = load_cache(cache_file)
    initial_cache_size = len(cache)

    # Find unique locations in new data
    unique_locations = df[location_col].dropna().unique()
    print(f"\nFound {len(unique_locations)} unique locations in new data")

    # Identify which are already cached
    cached_locations = [loc for loc in unique_locations if loc in cache]
    new_locations = [loc for loc in unique_locations if loc not in cache]

    print(f"  Already cached: {len(cached_locations)}")
    print(f"  Need to geocode: {len(new_locations)}")

    # Geocode only new locations
    if new_locations:
        print(f"\nGeocoding {len(new_locations)} new locations...")
        print(f"Estimated time: ~{len(new_locations) * 0.05 / 60:.1f} minutes\n")

        geolocator = Nominatim(user_agent="twitter_location_extractor", timeout=3)

        for i, location in enumerate(new_locations, 1):
            # Skip invalid locations
            if is_invalid_location(location):
                cache[location] = {
                    'loc_is_valid': False,
                    'loc_confidence': 'invalid',
                    'loc_method': 'filtered'
                }
                continue

            # Geocode
            result = geocode_location(location, geolocator)
            cache[location] = result

            # Progress
            if i % 10 == 0:
                print(f"  Geocoded {i}/{len(new_locations)} new locations...")

            # Rate limiting (Nominatim requires ~1 request/sec)
            time.sleep(0.05)

            # Save periodically (every 100 locations)
            if i % 100 == 0:
                with open(cache_file, 'wb') as f:
                    pickle.dump(cache, f)
                print(f"  ✓ Saved checkpoint at {i} locations")

        # Final save
        with open(cache_file, 'wb') as f:
            pickle.dump(cache, f)

        print(f"\n✓ Geocoded and cached {len(new_locations)} new locations")
        print(f"✓ Updated cache: {initial_cache_size} → {len(cache)} locations")
    else:
        print("\n✓ All locations already cached - no geocoding needed!")

    # Apply cache to dataframe
    print(f"\nApplying cached results to {len(df)} rows...")

    df_output = df.copy()
    df_output['loc_city'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_city'))
    df_output['loc_state'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_state'))
    df_output['loc_country'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_country'))
    df_output['loc_country_code'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_country_code'))
    df_output['loc_latitude'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_latitude'))
    df_output['loc_longitude'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_longitude'))
    df_output['loc_confidence'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_confidence', 'not_in_cache'))
    df_output['loc_normalized'] = df[location_col].map(lambda x: cache.get(x, {}).get('loc_normalized'))

    # Summary
    valid_count = (df_output['loc_confidence'].isin(['high', 'medium'])).sum()
    print(f"\n✓ Complete!")
    print(f"  Valid locations: {valid_count}/{len(df)} ({100*valid_count/len(df):.1f}%)")
    print(f"  Cache now contains: {len(cache)} total locations")
    print(f"  Added {len(cache) - initial_cache_size} new locations to cache")

    return df_output


# ============================================================================
# SIMPLE USAGE
# ============================================================================

if __name__ == "__main__":

    print("""
USAGE EXAMPLE:

# First time - process your initial data
df1 = pd.read_csv('h5n1_batch1.csv')
df1_processed = process_new_data(df1, cache_file='h5n1_locations.pkl')
df1_processed.to_csv('h5n1_batch1_with_locations.csv', index=False)

# Later - process new data (reuses cache, only geocodes new locations)
df2 = pd.read_csv('h5n1_batch2.csv')
df2_processed = process_new_data(df2, cache_file='h5n1_locations.pkl')
df2_processed.to_csv('h5n1_batch2_with_locations.csv', index=False)

# Even later - more new data (keeps building the cache)
df3 = pd.read_csv('h5n1_batch3.csv')
df3_processed = process_new_data(df3, cache_file='h5n1_locations.pkl')
df3_processed.to_csv('h5n1_batch3_with_locations.csv', index=False)

The cache grows automatically and you never geocode the same location twice!
    """)

    # Example with sample data
    print("\n" + "="*70)
    print("EXAMPLE RUN:")
    print("="*70)

    # Simulate first batch
    df_batch1 = pd.DataFrame({
        'userId': [1, 2, 3],
        'userLocation': ['Chicago, IL', 'London', 'Tokyo']
    })

    print("\n--- Processing Batch 1 ---")
    df1_result = process_new_data(df_batch1, cache_file='example_cache.pkl')
    print("\nResult preview:")
    print(df1_result[['userLocation', 'loc_city', 'loc_country']].to_string(index=False))

    # Simulate second batch with some overlapping locations
    df_batch2 = pd.DataFrame({
        'userId': [4, 5, 6],
        'userLocation': ['Chicago, IL', 'Paris', 'Berlin']  # Chicago already cached!
    })

    print("\n\n--- Processing Batch 2 ---")
    df2_result = process_new_data(df_batch2, cache_file='example_cache.pkl')
    print("\nResult preview:")
    print(df2_result[['userLocation', 'loc_city', 'loc_country']].to_string(index=False))

    print("\n" + "="*70)
    print("Notice: 'Chicago, IL' wasn't geocoded again - it used the cache!")
    print("="*70)
# Out:
# USAGE EXAMPLE:
#
# # First time - process your initial data
# df1 = pd.read_csv('h5n1_batch1.csv')
# df1_processed = process_new_data(df1, cache_file='h5n1_locations.pkl')
# df1_processed.to_csv('h5n1_batch1_with_locations.csv', index=False)
#
# # Later - process new data (reuses cache, only geocodes new locations)
# df2 = pd.read_csv('h5n1_batch2.csv')
# df2_processed = process_new_data(df2, cache_file='h5n1_locations.pkl')
# df2_processed.to_csv('h5n1_batch2_with_locations.csv', index=False)
#
# # Even later - more new data (keeps building the cache)
# df3 = pd.read_csv('h5n1_batch3.csv')
# df3_processed = process_new_data(df3, cache_file='h5n1_locations.pkl')
# df3_processed.to_csv('h5n1_batch3_with_locations.csv', index=False)
#
# The cache grows automatically and you never geocode the same location twice!
#
#
# ======================================================================
# EXAMPLE RUN:
# ======================================================================
#
# --- Processing Batch 1 ---
# ======================================================================
# INCREMENTAL GEOCODING
# ======================================================================
# ✓ Creating new cache
#
# Found 3 unique locations in new data
#   Already cached: 0
#   Need to geocode: 3
#
# Geocoding 3 new locations...
# Estimated time: ~0.0 minutes
#
#
# ✓ Geocoded and cached 3 new locations
# ✓ Updated cache: 0 → 3 locations
#
# Applying cached results to 3 rows...
#
# ✓ Complete!
#   Valid locations: 3/3 (100.0%)
#   Cache now contains: 3 total locations
#   Added 3 new locations to cache
#
# Result preview:
# userLocation loc_city    loc_country
#  Chicago, IL  Chicago  United States
#       London   London United Kingdom
#        Tokyo     None          Japan
#
#
# --- Processing Batch 2 ---
# ======================================================================
# INCREMENTAL GEOCODING
# ======================================================================
# ✓ Loaded existing cache with 3 locations
#
# Found 3 unique locations in new data
#   Already cached: 1
#   Need to geocode: 2
#
# Geocoding 2 new locations...
# Estimated time: ~0.0 minutes
#
#
# ✓ Geocoded and cached 2 new locations
# ✓ Updated cache: 3 → 5 locations
#
# Applying cached results to 3 rows...
#
# ✓ Complete!
#   Valid locations: 3/3 (100.0%)
#   Cache now contains: 5 total locations
#   Added 2 new locations to cache
#
# Result preview:
# userLocation loc_city   loc_country
#  Chicago, IL  Chicago United States
#        Paris    Paris        France
#       Berlin   Berlin       Germany
#
# ======================================================================
# Notice: 'Chicago, IL' wasn't geocoded again - it used the cache!
# ======================================================================
